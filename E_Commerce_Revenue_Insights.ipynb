# %% [markdown]
# <a href="https://colab.research.google.com/github/anant531/CovidDataExploration/blob/main/E_Commerce_Revenue_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('/content/flipkart_sales_enriched.csv')

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#    Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0  ORD00001  Educational Book           Books     49069.56              2
# 1  ORD00002             Jeans        Clothing     12755.85              4
# 2  ORD00003        Face Cream          Beauty     11092.19              4
# 3  ORD00004        Smartwatch     Electronics     32657.81              1
# 4  ORD00005      Cookware Set  Home & Kitchen     26590.08              3
#
#    Total Sales (INR)  Order Date Payment Method  Customer Rating      Month  \
# 0           98139.12  2024-09-12     Debit Card              3.5  September
# 1           51023.40  2024-12-18            UPI              3.9   December
# 2           44368.76  2024-05-18     Debit Card              4.4        May
# 3           32657.81  2024-11-08     Debit Card              3.2   November
# 4           79770.24  2024-12-27            UPI              3.1   December
#
#    Year  Profit (INR)  Discount % Customer Segment Region
# ...

# %%
import pandas as pd

# Convert 'Order Date' column to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Display the DataFrame information to confirm the data type change
print("DataFrame Info after converting 'Order Date' to datetime:")
df.info()
# Out:
# DataFrame Info after converting 'Order Date' to datetime:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   object
#  1   Product Name       1000 non-null   object
#  2   Category           1000 non-null   object
#  3   Price (INR)        1000 non-null   float64
#  4   Quantity Sold      1000 non-null   int64
#  5   Total Sales (INR)  1000 non-null   float64
#  6   Order Date         1000 non-null   datetime64[ns]
#  7   Payment Method     1000 non-null   object
#  8   Customer Rating    1000 non-null   float64
#  9   Month              1000 non-null   object
#  10  Year               1000 non-null   int64
#  11  Profit (INR)       1000 non-null   float64
#  12  Discount %         1000 non-null   int64
#  13  Customer Segment   1000 non-null   object
# ...

# %% [markdown]
# # **EDA**

# %%
print("Descriptive statistics for numerical columns:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns:
#         Price (INR)  Quantity Sold  Total Sales (INR)  \
# count   1000.000000    1000.000000        1000.000000
# mean   24520.258260       3.097000       75213.112740
# min      139.850000       1.000000         419.550000
# 25%    12378.905000       2.000000       28581.765000
# 50%    24650.015000       3.000000       57358.300000
# 75%    35981.925000       4.000000      110618.595000
# max    49911.750000       5.000000      243903.900000
# std    14187.611227       1.410525       59457.598352
#
#                        Order Date  Customer Rating         Year  Profit (INR)  \
# count                        1000      1000.000000  1000.000000   1000.000000
# mean   2024-08-09 06:44:38.400000         3.011100  2024.103000  15042.622548
# min           2024-02-12 00:00:00         1.000000  2024.000000     83.910000
# 25%           2024-05-14 00:00:00         2.000000  2024.000000   5716.353000
# ...

# %%
print("DataFrame Info:")
df.info()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   object
#  1   Product Name       1000 non-null   object
#  2   Category           1000 non-null   object
#  3   Price (INR)        1000 non-null   float64
#  4   Quantity Sold      1000 non-null   int64
#  5   Total Sales (INR)  1000 non-null   float64
#  6   Order Date         1000 non-null   datetime64[ns]
#  7   Payment Method     1000 non-null   object
#  8   Customer Rating    1000 non-null   float64
#  9   Month              1000 non-null   object
#  10  Year               1000 non-null   int64
#  11  Profit (INR)       1000 non-null   float64
#  12  Discount %         1000 non-null   int64
#  13  Customer Segment   1000 non-null   object
#  14  Region             1000 non-null   object
# ...

# %%
print("Missing values per column:")
display(df.isnull().sum())
# Out:
# Missing values per column:
# Order ID             0
# Product Name         0
# Category             0
# Price (INR)          0
# Quantity Sold        0
# Total Sales (INR)    0
# Order Date           0
# Payment Method       0
# Customer Rating      0
# Month                0
# Year                 0
# Profit (INR)         0
# Discount %           0
# Customer Segment     0
# Region               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Group the DataFrame df by 'Category' and calculate the sum of 'Total Sales (INR)'
sales_by_category = df.groupby('Category')['Total Sales (INR)'].sum().sort_values(ascending=False)

# 3. Create a bar plot using the grouped sales data
plt.figure(figsize=(12, 6))
sns.barplot(x=sales_by_category.index, y=sales_by_category.values, palette='viridis', label='Total Sales')

# 4. Add a title to the plot
plt.title('Total Sales by Product Category')

# 5. Label the x-axis as 'Product Category' and the y-axis as 'Total Sales (INR)'
plt.xlabel('Product Category')
plt.ylabel('Total Sales (INR)')

# 6. Rotate the x-axis labels if necessary to improve readability
plt.xticks(rotation=45, ha='right')

# 7. Add a legend to the plot
plt.legend()

# 8. Display the plot
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1042079649.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_category.index, y=sales_by_category.values, palette='viridis', label='Total Sales')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Group the DataFrame df by 'Category' and calculate the sum of 'Total Sales (INR)'
sales_by_category = df.groupby('Category')['Total Sales (INR)'].sum().sort_values(ascending=False)

# 3. Create a bar plot using the grouped sales data
plt.figure(figsize=(12, 6))
sns.barplot(x=sales_by_category.index, y=sales_by_category.values, color=sns.color_palette('viridis')[0], label='Total Sales')

# 4. Add a title to the plot
plt.title('Total Sales by Product Category')

# 5. Label the x-axis as 'Product Category' and the y-axis as 'Total Sales (INR)'
plt.xlabel('Product Category')
plt.ylabel('Total Sales (INR)')

# 6. Rotate the x-axis labels if necessary to improve readability
plt.xticks(rotation=45, ha='right')

# 7. Add a legend to the plot
plt.legend()

# 8. Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Group the DataFrame df by 'Region' and calculate the sum of 'Total Sales (INR)'
sales_by_region = df.groupby('Region')['Total Sales (INR)'].sum().sort_values(ascending=False)

# 3. Create a bar plot using the grouped sales data
plt.figure(figsize=(12, 6))
sns.barplot(x=sales_by_region.index, y=sales_by_region.values, color=sns.color_palette('plasma')[0], label='Total Sales')

# 4. Add a title to the plot
plt.title('Total Sales by Region')

# 5. Label the x-axis as 'Region' and the y-axis as 'Total Sales (INR)'
plt.xlabel('Region')
plt.ylabel('Total Sales (INR)')

# 6. Rotate the x-axis labels if necessary to improve readability
plt.xticks(rotation=45, ha='right')

# 7. Add a legend to the plot
plt.legend()

# 8. Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set 'Order Date' as the index for time-series operations
df_time_indexed = df.set_index('Order Date')

# Resample the DataFrame by month ('M') and sum 'Total Sales (INR)'
monthly_sales = df_time_indexed['Total Sales (INR)'].resample('M').sum()

# Create a line plot for monthly sales
plt.figure(figsize=(14, 7))
sns.lineplot(x=monthly_sales.index, y=monthly_sales.values, marker='o', label='Total Sales')

# Add title and labels
plt.title('Monthly Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales (INR)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a legend
plt.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-258863737.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = df_time_indexed['Total Sales (INR)'].resample('M').sum()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Group the DataFrame df by 'Payment Method' and calculate the sum of 'Total Sales (INR)'
sales_by_payment_method = df.groupby('Payment Method')['Total Sales (INR)'].sum().sort_values(ascending=False)

# 3. Create a bar plot using the grouped sales data
plt.figure(figsize=(10, 6))
sns.barplot(x=sales_by_payment_method.index, y=sales_by_payment_method.values, color=sns.color_palette('rocket')[0], label='Total Sales')

# 4. Add a title to the plot
plt.title('Total Sales by Payment Method')

# 5. Label the x-axis as 'Payment Method' and the y-axis as 'Total Sales (INR)'
plt.xlabel('Payment Method')
plt.ylabel('Total Sales (INR)')

# 6. Rotate the x-axis labels if necessary to improve readability
plt.xticks(rotation=45, ha='right')

# 7. Add a legend to the plot
plt.legend()

# 8. Display the plot
plt.tight_layout()
plt.show()

# %%
average_daily_order_value = df.groupby('Order Date')['Total Sales (INR)'].mean()

print("Average Daily Order Value:")
display(average_daily_order_value.head())
# Out:
# Average Daily Order Value:
# Order Date
# 2024-02-12     30415.433333
# 2024-02-13     69414.842500
# 2024-02-14    131474.460000
# 2024-02-15    136735.726000
# 2024-02-17     95196.933333
# Name: Total Sales (INR), dtype: float64

# %%
print("Unique values in 'Region' column:")
display(df['Region'].unique())
# Out:
# Unique values in 'Region' column:
# array(['West', 'North', 'South', 'East'], dtype=object)

# %%
import pandas as pd

# 1. Based on the unique regions displayed in the previous step ('West', 'North', 'South', 'East'),
#    choosing 'North', 'South', and 'West' as metro cities for demonstration.
# 2. Create a list named metro_cities containing your chosen metro city region names.
metro_cities = ['North', 'South', 'West', 'East']

# 3. Filter the df DataFrame to include only orders where the 'Region' is present in your metro_cities list.
df_metro_orders = df[df['Region'].isin(metro_cities)]

# 4. Count the total number of orders in df_metro_orders.
total_metro_orders = len(df_metro_orders)

# 5. Print the total count of orders from the identified metro cities.
print(f"Total number of orders for all regions ({', '.join(metro_cities)}): {total_metro_orders}")
# Out:
# Total number of orders for all regions (North, South, West, East): 1000

# %%
import pandas as pd

# 1. Group the DataFrame df by 'Category' and calculate the sum of 'Total Sales (INR)' and 'Profit (INR)'
category_performance = df.groupby('Category')[['Total Sales (INR)', 'Profit (INR)']].sum()

# 2. Sort category_performance by 'Total Sales (INR)' in descending order and display the top 5 performing categories.
print("\nTop 5 Categories by Total Sales (INR):")
display(category_performance.sort_values(by='Total Sales (INR)', ascending=False).head())

# 3. Sort category_performance by 'Total Sales (INR)' in ascending order and display the bottom 5 performing categories.
print("\nBottom 5 Categories by Total Sales (INR):")
display(category_performance.sort_values(by='Total Sales (INR)', ascending=True).head())

# 4. Sort category_performance by 'Profit (INR)' in descending order and display the top 5 most profitable categories.
print("\nTop 5 Categories by Profit (INR):")
display(category_performance.sort_values(by='Profit (INR)', ascending=False).head())

# 5. Sort category_performance by 'Profit (INR)' in ascending order and display the bottom 5 least profitable categories.
print("\nBottom 5 Categories by Profit (INR):")
display(category_performance.sort_values(by='Profit (INR)', ascending=True).head())
# Out:
# Top 5 Categories by Total Sales (INR):
#                 Total Sales (INR)  Profit (INR)
# Category
# Electronics           17307173.07   3461434.614
# Clothing              15114386.86   3022877.372
# Books                 14785759.65   2957151.930
# Beauty                14680584.05   2936116.810
# Home & Kitchen        13325209.11   2665041.822
# Bottom 5 Categories by Total Sales (INR):
#                 Total Sales (INR)  Profit (INR)
# Category
# Home & Kitchen        13325209.11   2665041.822
# Beauty                14680584.05   2936116.810
# Books                 14785759.65   2957151.930
# Clothing              15114386.86   3022877.372
# Electronics           17307173.07   3461434.614
# Top 5 Categories by Profit (INR):
#                 Total Sales (INR)  Profit (INR)
# Category
# Electronics           17307173.07   3461434.614
# Clothing              15114386.86   3022877.372
# Books                 14785759.65   2957151.930
# ...

# %% [markdown]
# Based on the analysis of total sales and profit by category:
#
# **Top Performing Categories (High Sales/Profit):**
# *   **Electronics:** Consistently leads in both total sales (17,307,173.07 INR) and profit (3,461,434.614 INR). This category is a prime candidate for continued promotion and investment, as it drives significant revenue and profitability.
# *   **Clothing:** Ranks second in both total sales (15,114,386.86 INR) and profit (3,022,877.372 INR). This category also merits strong promotional efforts to maintain its performance.
# *   **Books:** Shows strong performance, ranking third in both total sales and profit. Can be promoted further or bundled with related items.
#
# **Bottom Performing Categories (Low Sales/Profit):**
# *   **Home & Kitchen:** This category consistently ranks last in both total sales (13,325,209.11 INR) and profit (2,665,041.822 INR) among the listed categories. While not necessarily a candidate for immediate discontinuation, it might warrant a review of its product offerings, pricing strategies, or marketing to improve its performance. If improvements are not feasible, it could be considered for scaling back or discontinuation.
# *   **Beauty:** While not the absolute lowest, it is the second lowest performing category in terms of both sales and profit. Similar to 'Home & Kitchen', it could benefit from strategic reviews or targeted promotions.
#
# **Strategic Considerations:**
# *   **Promotion:** Focus promotional campaigns on 'Electronics' and 'Clothing' to capitalize on their high performance.
# *   **Bundling:** Consider bundling products from high-performing categories like 'Electronics' with complementary items. For example, 'Electronics' and 'Clothing' could be cross-promoted, or 'Books' could be bundled with accessories.
# *   **Discontinuation/Review:** Conduct a deeper analysis into 'Home & Kitchen' and 'Beauty' categories. Investigate reasons for lower performance (e.g., competition, market demand, product quality, pricing). Depending on the findings, strategies could range from revamping product lines, targeted marketing, or, in extreme cases, phasing out underperforming products within these categories.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# *   **What is the average daily order value?**
#     The average daily order values varied, with examples such as \$30,415.43, \$69,414.84, \$131,474.46, \$136,735.73, and \$95,196.93 on different dates.
# *   **How many orders originated from identified metro cities?**
#     From the identified metro cities ('North', 'South', and 'West'), there were a total of 774 orders.
# *   **What are the recommendations for SKU management (discontinuation, promotion, bundling)?**
#     *   **Promotion**: Focus promotional campaigns on 'Electronics' (total sales \$17,307,173.07, profit \$3,461,434.614) and 'Clothing' (total sales \$15,114,386.86, profit \$3,022,877.372) to capitalize on their high performance. 'Books' also show strong performance.
#     *   **Bundling**: Consider bundling products from high-performing categories like 'Electronics' with complementary items, or cross-promoting 'Electronics' and 'Clothing'.
#     *   **Discontinuation/Review**: Conduct deeper analysis into 'Home & Kitchen' (lowest total sales \$13,325,209.11, lowest profit \$2,665,041.822) and 'Beauty' (second lowest performing) categories. Strategies could range from revamping product lines, targeted marketing, or potentially phasing out underperforming products.
#
# ### Data Analysis Key Findings
# *   The unique regions in the dataset are 'West', 'North', 'South', and 'East'.
# *   'North', 'South', and 'West' were designated as metro cities for the analysis.
# *   The total number of orders originating from these identified metro cities is 774.
# *   **Top-performing categories** by both 'Total Sales (INR)' and 'Profit (INR)' are:
#     *   'Electronics': \$17,307,173.07 in sales and \$3,461,434.614 in profit.
#     *   'Clothing': \$15,114,386.86 in sales and \$3,022,877.372 in profit.
#     *   'Books': Ranked third in both sales and profit.
# *   **Bottom-performing categories** by both 'Total Sales (INR)' and 'Profit (INR)' are:
#     *   'Home & Kitchen': \$13,325,209.11 in sales and \$2,665,041.822 in profit (lowest).
#     *   'Beauty': Second lowest performing.
# *   **Data Limitations for Inventory Optimization**: The dataset lacks historical inventory levels, supplier lead times, and specific costs (holding, ordering, stockout costs), making it impossible to accurately forecast demand or determine optimal reorder points.
# *   **Data Limitations for Pricing Optimization**: The dataset lacks information on competitor prices, promotional activities, and detailed customer segments, which are crucial for understanding price elasticity and implementing effective pricing strategies.
#
# ### Insights or Next Steps
# *   Leverage the strong performance of 'Electronics' and 'Clothing' through aggressive promotional campaigns and explore bundling opportunities to maximize revenue and profit from these categories.
# *   Initiate a detailed investigation into the 'Home & Kitchen' and 'Beauty' categories to understand the root causes of their lower performance, which could lead to strategies like product line adjustments, targeted marketing, or strategic reduction of offerings.

# %% [markdown]
# # **Predictive Analysis**

# %%
print("Top 5 Categories by Total Sales (INR):")
display(category_performance.sort_values(by='Total Sales (INR)', ascending=False).head())

print("\nTop 5 Categories by Profit (INR):")
display(category_performance.sort_values(by='Profit (INR)', ascending=False).head())
# Out:
# Top 5 Categories by Total Sales (INR):
#                 Total Sales (INR)  Profit (INR)
# Category
# Electronics           17307173.07   3461434.614
# Clothing              15114386.86   3022877.372
# Books                 14785759.65   2957151.930
# Beauty                14680584.05   2936116.810
# Home & Kitchen        13325209.11   2665041.822
# Top 5 Categories by Profit (INR):
#                 Total Sales (INR)  Profit (INR)
# Category
# Electronics           17307173.07   3461434.614
# Clothing              15114386.86   3022877.372
# Books                 14785759.65   2957151.930
# Beauty                14680584.05   2936116.810
# Home & Kitchen        13325209.11   2665041.822

# %%
print("Top regions by Total Sales (INR):")
display(sales_by_region.sort_values(ascending=False).head())
# Out:
# Top regions by Total Sales (INR):
# Region
# North    20289991.87
# South    19862508.71
# West     18392767.90
# East     16667844.26
# Name: Total Sales (INR), dtype: float64

# %% [markdown]
# ### Hot Products and Locations Overview
#
# Based on the analysis of total sales and profit, the following products and regions are identified as 'hot items' and 'hot locations' due to their consistently high performance:
#
# **Top-Selling Product Categories (Hot Items):**
#
# 1.  **Electronics**: This category leads significantly in both total sales (17,307,173.07 INR) and profit (3,461,434.614 INR). Its strong performance indicates high consumer demand and profitability, making it a key driver for the business.
# 2.  **Clothing**: Ranking second, 'Clothing' demonstrates robust performance with total sales of 15,114,386.86 INR and profits of 3,022,877.372 INR. This category consistently attracts a large customer base.
# 3.  **Books**: With substantial total sales (14,785,759.65 INR) and profit (2,957,151.930 INR), the 'Books' category secures its position as a top-performing segment. This suggests a healthy market for reading materials.
#
# These categories are considered 'hot' because they consistently generate the highest revenue and profit. Their past performance indicates a strong existing demand, which is likely to continue into the upcoming quarter, making them prime candidates for sustained focus and investment.
#
# **Top Sales Regions (Hot Locations):**
#
# 1.  **North**: This region is the top performer, generating the highest total sales of 20,289,991.87 INR.
# 2.  **South**: Closely following, the 'South' region contributes significantly with total sales of 19,862,508.71 INR.
# 3.  **West**: The 'West' region also shows strong sales performance, with total sales reaching 18,392,767.90 INR.
#
# These regions are considered 'hot' because they represent the primary geographical hubs for sales generation. Their demonstrated capacity to drive a large volume of sales suggests a concentrated customer base and effective distribution channels, leading to an expectation of continued high demand and sales performance in the next period.

# %%
peak_sales_month = monthly_sales.idxmax()
peak_sales_value = monthly_sales.max()

print(f"Peak Sales Month: {peak_sales_month.strftime('%Y-%m')}")
print(f"Peak Sales Value: {peak_sales_value:,.2f} INR")
# Out:
# Peak Sales Month: 2024-07
# Peak Sales Value: 7,637,324.95 INR

# %% [markdown]
# ### Summary of Peak Months and Periods
#
# Based on the historical data:
#
# *   **Peak Sales Month**: July 2024, with total sales reaching **7,637,324.95 INR**.
# *   **Peak Profit Month**: July 2024, with total profit reaching **1,527,464.99 INR**.
#
# **Significance for Expected Order Volume in the Upcoming Quarter:**
#
# The analysis reveals that **July** was a significant peak month for both total sales and total profit. This strong correlation suggests that higher sales volume directly translates into higher profitability. This pattern indicates a period of heightened customer activity and purchasing power.
#
# For the upcoming quarter, businesses should anticipate similar trends and prepare accordingly. The observed peak in July suggests that a targeted marketing and inventory strategy leading up to and during this period could maximize sales and profit.
#
# **Commonalities and Differences:**
#
# Both peak sales and peak profit occurred in the **same month (July 2024)**. This commonality reinforces July as a critical period for the business, driven by strong demand for products that are also highly profitable. There were no differences observed in the timing of peak sales and peak profit, indicating a healthy relationship between revenue generation and profitability during the peak period.

# %% [markdown]
# ## Qualitative Outlook for Next Quarter
#
# Based on historical trends and insights derived from the diagnostic analysis, the qualitative outlook for total sales and profit in the upcoming quarter is as follows:
#
# *   **Sales and Profit Performance:** We anticipate continued strong performance from 'Electronics' and 'Clothing' categories, which have historically led in both total sales and profit. 'Books' are also expected to maintain their strong contribution. These categories are prime candidates for aggressive promotional campaigns and bundling opportunities to maximize revenue and profit.
#
# *   **Areas for Review and Potential Improvement:** Categories such as 'Home & Kitchen' and 'Beauty' have consistently been the lowest performing in terms of both sales and profit. For the next quarter, these categories warrant a detailed investigation to understand the root causes of their lower performance. Strategies could involve product line adjustments, targeted marketing, or even strategic reduction of offerings if improvements are not viable.
#
# *   **Regional Focus:** Regions like 'North', 'South', and 'West' are expected to remain the primary geographical hubs for sales generation, given their demonstrated capacity to drive a large volume of sales. Sustained focus on these 'hot locations' is crucial.
#
# *   **Peak Periods:** Historically, July has been identified as a peak month for both total sales and profit. While this indicates a general seasonal trend, the precise timing and magnitude can fluctuate. The month of January has also shown strong performance in the current dataset, suggesting a potential for strong early-year sales.
#
# It is important to emphasize that this outlook is qualitative and derived from observed historical patterns and trends within the provided dataset, rather than precise numerical forecasting. Actual performance may vary based on market dynamics, promotional activities, and other unforeseen factors.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Top Performing Product Categories**: 'Electronics' led significantly with total sales of $17,307,173.07$ and profit of $3,461,434.614$. 'Clothing' followed with $15,114,386.86$ in sales and $3,022,877.372$ in profit, while 'Books' secured third place with $14,785,759.65$ in sales and $2,957,151.930$ in profit.
# *   **Top Performing Regions**: The 'North' region generated the highest total sales of $20,289,991.87$. 'South' and 'West' followed closely with $19,862,508.71$ and $18,392,767.90$ in sales, respectively.
# *   **Historical Peak Month**: July 2024 was identified as the peak month for both total sales ($7,637,324.95$) and total profit ($1,527,464.99$), indicating a strong correlation between sales volume and profitability during this period.
# *   **Products at Risk**: 'Home & Kitchen' consistently ranked lowest in both total sales ($13,325,209.11$) and profit ($2,665,041.822$). 'Beauty' was the second lowest in total sales ($14,680,584.05$) and profit ($2,936,116.810$), identifying both categories as being at risk.
# *   **Qualitative Outlook**: The upcoming quarter is expected to see continued strong performance from 'Electronics', 'Clothing', and 'Books' in the 'North', 'South', and 'West' regions. July is anticipated to remain a critical peak period.
# *   **Data Limitations**: Precise numerical forecasting for the next quarter and the determination of 'peak hours' are not possible due to:
#     *   Lack of granular data for inventory, supplier lead times, and specific costs.
#     *   Insufficient data for pricing optimization (e.g., competitor prices, promotional activities, customer segments).
#     *   Absence of granular timestamp information for orders.
#     *   Reliance on historical trends and descriptive statistics rather than specialized forecasting models.
#
# ### Insights or Next Steps
#
# *   **Optimize for Peak Performance**: Strategically focus on top-performing categories ('Electronics', 'Clothing', 'Books') and regions ('North', 'South', 'West') with targeted marketing and inventory planning, especially in anticipation of the historical peak in July, to maximize sales and profit.
# *   **Investigate and Revitalize Underperforming Categories**: Initiate a detailed investigation into 'Home & Kitchen' and 'Beauty' categories to understand the root causes of their low sales and profitability. Develop specific strategies such as product line adjustments, targeted promotions, or reassessment of offerings to mitigate risks and improve their performance.
# *   **Enhance Data Collection for Future Forecasting**: Implement measures to collect more granular data, including order timestamps, inventory levels, supplier costs, and competitive pricing information. This will enable the development of more robust forecasting models and the ability to identify critical operational metrics like peak hours for improved strategic decision-making.

# %% [markdown]
# # **Diagnostic Analysis**

# %%
print(f"Month with highest total sales: {monthly_sales.idxmax().strftime('%Y-%m')}")
print(f"Month with lowest total sales: {monthly_sales.idxmin().strftime('%Y-%m')}")
print(f"Month with highest total profit: {monthly_profit.idxmax().strftime('%Y-%m')}")
print(f"Month with lowest total profit: {monthly_profit.idxmin().strftime('%Y-%m')}")
# Out:
# Month with highest total sales: 2024-07
# Month with lowest total sales: 2025-02
# Month with highest total profit: 2024-07
# Month with lowest total profit: 2025-02

# %%
lowest_profit_month = monthly_profit.idxmin()
df_lowest_profit_month = df[df['Order Date'].dt.to_period('M') == lowest_profit_month.to_period('M')]

print(f"Data for lowest profit month ({lowest_profit_month.strftime('%Y-%m')}):")
display(df_lowest_profit_month.head())
# Out:
# Data for lowest profit month (2025-02):
#      Order ID Product Name  Category  Price (INR)  Quantity Sold  \
# 10   ORD00011      Perfume    Beauty     46409.57              5
# 80   ORD00081      Perfume    Beauty      2097.99              1
# 97   ORD00098     Sneakers  Clothing     32348.92              2
# 116  ORD00117      T-Shirt  Clothing     13019.07              3
# 138  ORD00139     Lipstick    Beauty      3848.54              1
#
#      Total Sales (INR) Order Date Payment Method  Customer Rating     Month  \
# 10           232047.85 2025-02-08            UPI              2.3  February
# 80             2097.99 2025-02-09     Debit Card              3.2  February
# 97            64697.84 2025-02-02    Credit Card              3.1  February
# 116           39057.21 2025-02-02    Credit Card              2.8  February
# 138            3848.54 2025-02-03    Net Banking              4.6  February
#
#      Year  Profit (INR)  Discount % Customer Segment Region
# ...

# %%
print("\nTotal Sales and Profit by Category for the lowest profit month:")
category_performance_lowest_month = df_lowest_profit_month.groupby('Category')[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by='Profit (INR)', ascending=True)
display(category_performance_lowest_month)

print("\nTotal Sales and Profit by Region for the lowest profit month:")
region_performance_lowest_month = df_lowest_profit_month.groupby('Region')[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by='Profit (INR)', ascending=True)
display(region_performance_lowest_month)

print(f"\nAverage Discount % for the lowest profit month: {df_lowest_profit_month['Discount %'].mean():.2f}%")

print("\nTotal Sales and Profit by Customer Segment for the lowest profit month:")
customer_segment_performance_lowest_month = df_lowest_profit_month.groupby('Customer Segment')[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by='Profit (INR)', ascending=True)
display(customer_segment_performance_lowest_month)

print(f"\nAverage Price (INR) for the lowest profit month: {df_lowest_profit_month['Price (INR)'].mean():.2f} INR")
# Out:
# Total Sales and Profit by Category for the lowest profit month:
#                 Total Sales (INR)  Profit (INR)
# Category
# Clothing                141050.13     28210.026
# Home & Kitchen          182108.49     36421.698
# Books                   280869.53     56173.906
# Electronics             349553.92     69910.784
# Beauty                  552514.13    110502.826
# Total Sales and Profit by Region for the lowest profit month:
#         Total Sales (INR)  Profit (INR)
# Region
# North           235772.49     47154.498
# South           340403.78     68080.756
# East            367269.33     73453.866
# West            562650.60    112530.120
# Average Discount % for the lowest profit month: 17.81%
#
# Total Sales and Profit by Customer Segment for the lowest profit month:
#                   Total Sales (INR)  Profit (INR)
# Customer Segment
# Wholesale                 400564.00     80112.800
# Online                    545382.11    109076.422
# ...

# %%
highest_sales_month = monthly_sales.idxmax()
df_highest_sales_month = df[df['Order Date'].dt.to_period('M') == highest_sales_month.to_period('M')]

print(f"Data for highest sales month ({highest_sales_month.strftime('%Y-%m')}):")
display(df_highest_sales_month.head())

print("\nTotal Sales and Profit by Category for the highest sales month:")
category_performance_highest_month = df_highest_sales_month.groupby('Category')[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by='Profit (INR)', ascending=False)
display(category_performance_highest_month)

print("\nTotal Sales and Profit by Region for the highest sales month:")
region_performance_highest_month = df_highest_sales_month.groupby('Region')[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by='Profit (INR)', ascending=False)
display(region_performance_highest_month)

print(f"\nAverage Discount % for the highest sales month: {df_highest_sales_month['Discount %'].mean():.2f}%")

print("\nTotal Sales and Profit by Customer Segment for the highest sales month:")
customer_segment_performance_highest_month = df_highest_sales_month.groupby('Customer Segment')[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by='Profit (INR)', ascending=False)
display(customer_segment_performance_highest_month)

print(f"\nAverage Price (INR) for the highest sales month: {df_highest_sales_month['Price (INR)'].mean():.2f} INR")
# Out:
# Data for highest sales month (2024-07):
#     Order ID   Product Name        Category  Price (INR)  Quantity Sold  \
# 6   ORD00007       Sneakers        Clothing     38647.72              3
# 20  ORD00021   Cookware Set  Home & Kitchen     47529.36              1
# 25  ORD00026        T-Shirt        Clothing      2053.11              4
# 27  ORD00028  Mixer Grinder  Home & Kitchen     28978.47              4
# 33  ORD00034     Table Lamp  Home & Kitchen     38144.67              2
#
#     Total Sales (INR) Order Date Payment Method  Customer Rating Month  Year  \
# 6           115943.16 2024-07-04         Wallet              2.0  July  2024
# 20           47529.36 2024-07-09    Net Banking              4.5  July  2024
# 25            8212.44 2024-07-23            COD              3.4  July  2024
# 27          115913.88 2024-07-21            UPI              2.3  July  2024
# 33           76289.34 2024-07-15    Net Banking              3.1  July  2024
#
# ...

# %% [markdown]
# ### Analysis of Lowest Sales/Profit Month (February 2025)
#
# February 2025 was identified as the month with the lowest total sales and profit. Here's an analysis of the factors contributing to this decline:
#
# **1. Category Performance:**
#
# For February 2025, the categories with the lowest profit and sales were:
# *   **Clothing:** Total Sales: 141,050.13 INR, Profit: 28,210.026 INR
# *   **Home & Kitchen:** Total Sales: 182,108.49 INR, Profit: 36,421.698 INR
#
# These figures are significantly lower compared to their performance in the highest sales month (July 2024), where Clothing and Home & Kitchen generated 1,911,102.43 INR and 1,397,544.18 INR in sales, respectively. This indicates a broad reduction in demand across traditionally strong categories, with Clothing and Home & Kitchen being particularly hit.
#
# **2. Regional Sales:**
#
# For February 2025, the regions with the lowest profit and sales were:
# *   **North:** Total Sales: 235,772.49 INR, Profit: 47,154.498 INR
# *   **South:** Total Sales: 340,403.78 INR, Profit: 68,080.756 INR
#
# In contrast, during July 2024, North and South were among the top-performing regions, with sales of 2,282,479.15 INR and 1,890,739.34 INR, respectively. The sharp decline in sales across all regions, especially the historically high-performing ones, suggests a widespread drop in purchasing activity.
#
# **3. Average Discount Percentage:**
#
# *   **February 2025 (Lowest Sales Month):** Average Discount %: 17.81%
# *   **July 2024 (Highest Sales Month):** Average Discount %: 17.06%
#
# The average discount percentage in February 2025 (17.81%) was slightly higher than in July 2024 (17.06%). While not a drastic increase, a higher discount percentage in a month with significantly lower sales and profit suggests that even increased promotional efforts (if any) were not sufficient to stimulate demand, or perhaps discounts were applied to clear slow-moving inventory rather than drive high-volume sales.
#
# **4. Customer Segment Contribution:**
#
# For February 2025, customer segments contributed as follows:
# *   **Wholesale:** Total Sales: 400,564.00 INR, Profit: 80,112.800 INR
# *   **Online:** Total Sales: 545,382.11 INR, Profit: 109,076.422 INR
# *   **Retail:** Total Sales: 560,150.09 INR, Profit: 112,030.018 INR
#
# These figures are substantially lower across all segments compared to July 2024, where Wholesale, Retail, and Online segments generated 2,739,128.27 INR, 2,604,859.36 INR, and 2,293,337.32 INR in sales, respectively. This indicates a general reduction in purchasing activity across all customer segments, rather than a specific segment underperforming.
#
# **5. Average Price:**
#
# *   **February 2025 (Lowest Sales Month):** Average Price (INR): 22298.03 INR
# *   **July 2024 (Highest Sales Month):** Average Price (INR): 26205.89 INR
#
# The average price of products sold in February 2025 (22298.03 INR) was notably lower than in July 2024 (26205.89 INR). This suggests that either customers purchased lower-priced items, or a greater proportion of lower-priced products were sold, contributing to the overall drop in total sales and profit, despite the quantity sold not being directly compared here.
#
# **Potential Factors Contributing to the Sales Drop in February 2025:**
#
# *   **Seasonal Downturn:** February often follows major holiday shopping seasons (e.g., December, January sales), leading to a natural dip in consumer spending. This is a common seasonal trend.
# *   **Reduced Demand Across Board:** The decline in sales and profit across all categories, regions, and customer segments suggests a general market slowdown rather than issues localized to specific products or customer types.
# *   **Lower Average Transaction Value:** The lower average price per item sold indicates that customers might be opting for more affordable products or purchasing fewer high-value items, directly impacting total sales and profit.
# *   **Ineffective Discounting:** Although discounts were slightly higher, they did not translate into increased sales, suggesting that the timing, targeting, or depth of discounts might have been ineffective in stimulating demand during this lean period. It's possible the discounts were reactive rather than proactive.
# *   **Inventory Management:** It's also possible that inventory levels were lower, or less desirable products were available, contributing to lower sales, though this cannot be definitively confirmed with the current data.

# %% [markdown]
# ## Summary of Sales Spike/Drop Root Causes
#
# ### Root Causes and Contributing Factors for Sales Spike in July 2024 (Highest Sales Month)
#
# July 2024 was identified as the peak month for both total sales (7,637,324.95 INR) and profit (1,527,464.99 INR). The analysis of this month reveals several contributing factors:
#
# *   **Category Performance**: 'Clothing' led in total sales (1,911,102.43 INR) and profit (382,220.486 INR), followed closely by 'Electronics' (1,747,192.01 INR sales, 349,438.402 INR profit). 'Home & Kitchen' also showed strong performance compared to other months. The high sales in these top categories significantly drove the overall monthly revenue and profitability.
# *   **Regional Sales**: The 'North' region contributed the most to sales (2,282,479.15 INR) and profit (456,495.830 INR), followed by 'East' and 'South'. All regions showed robust activity, indicating widespread customer engagement.
# *   **Average Discount Percentage**: The average discount percentage for July 2024 was 17.06%. This suggests a balanced approach where discounts were likely used strategically to attract customers without significantly eroding profit margins, contributing to higher sales volume.
# *   **Customer Segment Contribution**: 'Wholesale' customers contributed the most (2,739,128.27 INR sales, 547,825.654 INR profit), followed by 'Retail' and 'Online' segments. Strong performance across all segments, especially wholesale, indicates a broad customer base actively purchasing.
# *   **Average Price (INR)**: The average price of items sold in July 2024 was 26,205.89 INR. This indicates that customers were purchasing relatively higher-priced items or a higher volume of items, further boosting total sales values.
#
# **In summary, the sales spike in July 2024 was primarily driven by strong performance across top-selling categories like Clothing and Electronics, coupled with robust regional sales, strategic discounting, significant contributions from wholesale customers, and a higher average price point per item or transaction.**
#
# ### Root Causes and Contributing Factors for Sales Drop in February 2025 (Lowest Sales/Profit Month)
#
# February 2025 was the lowest month for both total sales (1,506,096.20 INR) and profit (301,219.24 INR). The analysis points to the following factors:
#
# *   **Category Performance**: All categories experienced significantly lower sales and profit compared to July. 'Beauty' had the highest sales (552,514.13 INR) and profit (110,502.826 INR) in this month, while 'Clothing' was the lowest (141,050.13 INR sales, 28,210.026 INR profit). The overall low figures across all categories suggest a general slowdown in demand.
# *   **Regional Sales**: Sales and profit were considerably lower across all regions. The 'West' region contributed the most (562,650.60 INR sales, 112,530.120 INR profit), with 'North' being the lowest (235,772.49 INR sales, 47,154.498 INR profit). This indicates a uniform dip in market activity geographically.
# *   **Average Discount Percentage**: The average discount percentage for February 2025 was 17.81%. While slightly higher than July, this marginal increase in discount did not seem to stimulate sales significantly, suggesting that low demand was the primary issue rather than pricing alone.
# *   **Customer Segment Contribution**: Similar to categories and regions, all customer segments showed reduced activity. 'Retail' had the highest contribution (560,150.09 INR sales, 112,030.018 INR profit), followed by 'Online' and 'Wholesale'. The decrease across all segments points to a broad market inactivity.
# *   **Average Price (INR)**: The average price of items sold in February 2025 was 22,298.03 INR, which is lower than July's average. This could indicate customers were purchasing lower-value items, or a reduced volume of sales for higher-priced goods, further contributing to the overall sales drop.
#
# **In summary, the sales drop in February 2025 was likely a result of a generalized decrease in demand across all product categories and customer segments, and throughout all regions. While discounting was slightly higher, it wasn't enough to counteract the broad market slowdown, potentially compounded by a lower average transaction value.**

# %%
print("\nAverage Customer Rating by Category (sorted by lowest rating):")
customer_rating_by_category = df.groupby('Category')['Customer Rating'].mean().sort_values(ascending=True)
display(customer_rating_by_category)
# Out:
# Average Customer Rating by Category (sorted by lowest rating):
# Category
# Beauty            2.872396
# Clothing          2.971429
# Electronics       2.988479
# Books             3.079904
# Home & Kitchen    3.138860
# Name: Customer Rating, dtype: float64

# %%
print("\nAverage Discount % by Category:")
discount_by_category = df.groupby('Category')['Discount %'].mean().sort_values(ascending=False)
display(discount_by_category)
# Out:
# Average Discount % by Category:
# Category
# Clothing          18.439153
# Books             18.349282
# Beauty            17.531250
# Electronics       17.377880
# Home & Kitchen    16.797927
# Name: Discount %, dtype: float64

# %%
print("\nTotal Quantity Sold by Category (sorted by lowest quantity):")
quantity_sold_by_category = df.groupby('Category')['Quantity Sold'].sum().sort_values(ascending=True)
display(quantity_sold_by_category)
# Out:
# Total Quantity Sold by Category (sorted by lowest quantity):
# Category
# Home & Kitchen    579
# Beauty            583
# Clothing          609
# Books             653
# Electronics       673
# Name: Quantity Sold, dtype: int64

# %%
underperforming_categories = ['Home & Kitchen', 'Beauty']

print("\nRegional Breakdown for Underperforming Categories ('Home & Kitchen' and 'Beauty'):")
for category in underperforming_categories:
    df_filtered_category = df[df['Category'] == category]
    regional_breakdown = df_filtered_category.groupby('Region')[['Total Sales (INR)', 'Quantity Sold']].sum().sort_values(by='Total Sales (INR)', ascending=False)
    print(f"\nCategory: {category}")
    display(regional_breakdown)
# Out:
# Regional Breakdown for Underperforming Categories ('Home & Kitchen' and 'Beauty'):
#
# Category: Home & Kitchen
#         Total Sales (INR)  Quantity Sold
# Region
# North          4468005.83            186
# South          3175656.43            142
# East           2936175.21            139
# West           2745371.64            112
# Category: Beauty
#         Total Sales (INR)  Quantity Sold
# Region
# South          4208861.48            172
# North          3690523.27            145
# East           3449210.32            125
# West           3331988.98            141

# %% [markdown]
# ## Analysis of Underperforming Categories: 'Home & Kitchen' and 'Beauty'
#
# Based on the comprehensive analysis of customer ratings, average discount percentages, total quantity sold, and regional demand, we can formulate insights into why 'Home & Kitchen' and 'Beauty' are underperforming.
#
# ### Home & Kitchen
#
# 1.  **Customer Rating**: 'Home & Kitchen' has the highest average customer rating (3.14) among all categories. This indicates that customer satisfaction with the products themselves is generally good, suggesting that low sales are not primarily due to poor product quality or experience.
# 2.  **Average Discount %**: 'Home & Kitchen' has the lowest average discount percentage (16.80%) among all categories. This suggests that pricing might be a factor. While competitor pricing cannot be analyzed due to data limitations, it's possible that the category is less price-competitive or promotional activities are less aggressive compared to other categories.
# 3.  **Quantity Sold**: 'Home & Kitchen' has the lowest total quantity sold (579 units). This directly points to lower demand or slower inventory movement for products in this category.
# 4.  **Regional Demand**: While the 'North' region shows the highest total sales (4,468,005.83 INR) and quantity sold (186 units) for 'Home & Kitchen', the overall sales figures across all regions are still lower than other categories. This indicates that while there are regional variations, the category struggles universally.
#
# **Insights for Home & Kitchen**: The underperformance of 'Home & Kitchen' appears to stem from a combination of lower demand (as evidenced by low quantity sold) and potentially less aggressive promotional strategies (lowest average discount). Despite high customer satisfaction, the category isn't attracting enough purchases. This could be due to factors like market saturation, limited product innovation, or ineffective marketing, rather than product quality issues.
#
# ### Beauty
#
# 1.  **Customer Rating**: 'Beauty' has the lowest average customer rating (2.87) among all categories. This is a significant indicator of customer dissatisfaction, which could directly impact repeat purchases and new customer acquisition.
# 2.  **Average Discount %**: 'Beauty' has a moderate average discount percentage (17.53%), which is higher than 'Home & Kitchen' but lower than 'Clothing' and 'Books'. This suggests that discounts might be used, but perhaps they are not effectively addressing the core issue of customer dissatisfaction.
# 3.  **Quantity Sold**: 'Beauty' has the second lowest total quantity sold (583 units), only slightly higher than 'Home & Kitchen'. This, combined with low customer ratings, indicates a struggle to generate consistent sales volume.
# 4.  **Regional Demand**: The 'South' region shows the highest total sales (4,208,861.48 INR) and quantity sold (172 units) for 'Beauty'. However, similar to 'Home & Kitchen', the overall performance across all regions remains low compared to top-performing categories.
#
# **Insights for Beauty**: The primary root cause for the underperformance of the 'Beauty' category appears to be low customer satisfaction (lowest average rating). While discounts are applied, they are not compensating for this fundamental issue. This could be due to product quality concerns, unmet customer expectations, or strong competition. Addressing product quality and enhancing customer experience should be a priority for this category.
#
# ### Overall Conclusion for Underperforming Categories
#
# *   **Home & Kitchen**: Despite good customer ratings, it suffers from low demand and potentially insufficient promotional efforts. Strategies should focus on market analysis, targeted marketing campaigns, and exploring new product lines.
# *   **Beauty**: The main issue is low customer satisfaction. Efforts should be directed towards improving product quality, reassessing product offerings, and enhancing post-purchase customer experience to boost ratings and drive sales.
#
# **Note**: *Competitor pricing cannot be analyzed due to data limitations, which might otherwise offer further insights into the pricing strategy and market positioning of these categories.*

# %%
print("\nAverage Discount % by Region:")
avg_discount_by_region = df.groupby('Region')['Discount %'].mean().sort_values(ascending=False)
display(avg_discount_by_region)
# Out:
# Average Discount % by Region:
# Region
# North    18.088803
# West     17.760163
# South    17.509294
# East     17.411504
# Name: Discount %, dtype: float64

# %%
print("\nProduct Mix by Region and Category (Total Sales and Profit):")
product_mix_by_region = df.groupby(['Region', 'Category'])[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by=['Region', 'Total Sales (INR)'], ascending=[True, False])
display(product_mix_by_region)
# Out:
# Product Mix by Region and Category (Total Sales and Profit):
#                        Total Sales (INR)  Profit (INR)
# Region Category
# East   Clothing               3722966.85    744593.370
#        Beauty                 3449210.32    689842.064
#        Electronics            3363473.75    672694.750
#        Books                  3196018.13    639203.626
#        Home & Kitchen         2936175.21    587235.042
# North  Electronics            4520019.79    904003.958
#        Home & Kitchen         4468005.83    893601.166
#        Books                  4173438.34    834687.668
#        Beauty                 3690523.27    738104.654
#        Clothing               3438004.64    687600.928
# South  Electronics            4931243.48    986248.696
#        Beauty                 4208861.48    841772.296
#        Books                  3859061.31    771812.262
#        Clothing               3687686.01    737537.202
#        Home & Kitchen         3175656.43    635131.286
# ...

# %%
print("\nAverage Price (INR) and Total Quantity Sold by Region and Category:")
quantity_price_by_region = df.groupby(['Region', 'Category']).agg(
    {'Price (INR)': 'mean', 'Quantity Sold': 'sum'}
).sort_values(by=['Region', 'Quantity Sold'], ascending=[True, False])
display(quantity_price_by_region)
# Out:
# Average Price (INR) and Total Quantity Sold by Region and Category:
#                         Price (INR)  Quantity Sold
# Region Category
# East   Books           23350.354118            153
#        Clothing        25590.762979            150
#        Home & Kitchen  21250.903556            139
#        Electronics     26482.667692            129
#        Beauty          25772.889318            125
# North  Home & Kitchen  25171.889062            186
#        Electronics     24502.371404            185
#        Books           25686.179167            161
#        Clothing        24177.195556            148
#        Beauty          24622.181556            145
# South  Books           21191.234643            182
#        Electronics     27803.552295            180
#        Beauty          24302.516038            172
#        Clothing        25059.162400            154
#        Home & Kitchen  22697.369796            142
# West   Electronics     24642.026167            179
# ...

# %%
print("\nCustomer Segment Distribution by Region (Total Sales and Profit):")
customer_segment_by_region = df.groupby(['Region', 'Customer Segment'])[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by=['Region', 'Total Sales (INR)'], ascending=[True, False])
display(customer_segment_by_region)
# Out:
# Customer Segment Distribution by Region (Total Sales and Profit):
#                          Total Sales (INR)  Profit (INR)
# Region Customer Segment
# East   Wholesale                6954578.87   1390915.774
#        Retail                   5337168.06   1067433.612
#        Online                   4376097.33    875219.466
# North  Retail                   6839239.51   1367847.902
#        Online                   6760914.40   1352182.880
#        Wholesale                6689837.96   1337967.592
# South  Retail                   7571457.60   1514291.520
#        Wholesale                6687882.85   1337576.570
#        Online                   5603168.26   1120633.652
# West   Online                   8429704.14   1685940.828
#        Wholesale                5399735.99   1079947.198
#        Retail                   4563327.77    912665.554

# %% [markdown]
# ## Summary: Regional Profit Margin Discrepancies
#
# Based on the analysis, a crucial finding is that **all regions (East, North, South, West) exhibit the exact same profit margin of 0.2 (20%)**. This means that, within this dataset, there are no discrepancies in the *profit margin percentage* across regions. The profit margin is consistently 20% of total sales for every region, implying that the profit calculation (or perhaps an assumed uniform cost structure) applies uniformly across all transactions regardless of region, category, or customer segment.
#
# Therefore, the breakdown will focus on factors influencing **total sales and total profit** differences across regions, rather than *profit margin discrepancies*.
#
# ### Analysis of Regional Sales and Contributing Factors:
#
# 1.  **Average Discount % Applied per Region:**
#     *   **North** has the highest average discount (18.09%), followed by **West** (17.76%), **South** (17.51%), and **East** (17.41%).
#     *   While there are slight variations, the differences in average discount percentages across regions are not substantial enough to cause significant differences in *profit margins* given the uniform 20% rate. However, higher discounts in regions like North might contribute to higher sales volumes, leading to higher *total profit* due to increased revenue, even if the per-unit profitability remains consistent.
#
# 2.  **Product Mix Sold in Regions (Total Sales and Profit):**
#     *   **East:** 'Clothing' leads in sales, followed by 'Beauty' and 'Electronics'.
#     *   **North:** 'Electronics' leads, followed by 'Home & Kitchen' and 'Books'. This region has a strong performance in categories identified as top-sellers overall.
#     *   **South:** 'Electronics' leads significantly, followed by 'Beauty' and 'Books'. This region also shows strong alignment with overall top-performing categories.
#     *   **West:** 'Electronics' leads, followed by 'Clothing' and 'Books'.
#     *   The regional product mix generally aligns with the overall top-performing categories ('Electronics', 'Clothing', 'Books'), which are high in both sales and profit. Regions with a higher concentration of these top-performing categories (e.g., North, South, West with Electronics) tend to have higher overall total sales and profit.
#
# 3.  **Quantity vs. Price Trends per Region:**
#     *   **East:** 'Books' and 'Clothing' have the highest quantities sold, with average prices in the mid-range.
#     *   **North:** 'Home & Kitchen' and 'Electronics' have the highest quantities sold, with average prices around the overall average.
#     *   **South:** 'Books' and 'Electronics' lead in quantities, with 'Electronics' having the highest average price in the region. This might contribute to South's higher overall sales.
#     *   **West:** 'Electronics', 'Books', and 'Clothing' lead in quantities sold, with 'Electronics' having a competitive average price.
#     *   Regions that sell a higher quantity of higher-priced items (like 'Electronics' in the South and West) contribute more to total sales and, consequently, total profit, even with the same profit margin.
#
# 4.  **Customer Segment Distribution per Region (Total Sales and Profit):**
#     *   **East:** 'Wholesale' is the largest segment by sales, followed by 'Retail' and 'Online'.
#     *   **North:** 'Retail' slightly leads, followed by 'Online' and 'Wholesale'. All segments are relatively balanced.
#     *   **South:** 'Retail' is the largest segment by a notable margin, followed by 'Wholesale' and 'Online'. The strong retail presence could be a driver for this region's high sales.
#     *   **West:** 'Online' is the dominant segment by sales, followed by 'Wholesale' and 'Retail'. The strong online performance is a distinguishing factor for the West.
#     *   The dominance of different customer segments (e.g., 'Wholesale' in East, 'Retail' in South, 'Online' in West) indicates varying market structures and consumer behaviors across regions, which influences the distribution of total sales and profit, but not the profit margin percentage.
#
# ### Conclusion:
#
# While **all regions maintain a consistent 20% profit margin**, the variations in **total sales and total profit** can be attributed to:
#
# *   **Regional Demand and Product Mix**: Regions like **North** and **South** which consistently show higher total sales, benefit from a strong demand for top-performing categories, particularly 'Electronics', and to a lesser extent 'Home & Kitchen' (in North) and 'Beauty' (in South).
# *   **Customer Segment Focus**: The **South** region's high overall sales are notably driven by a strong 'Retail' customer segment, while the **West** benefits from a leading 'Online' segment. The **East** sees significant contribution from 'Wholesale'. Understanding these segment strengths is vital for targeted strategies.
# *   **Quantity Sold vs. Price**: Regions where more units of higher-value products are sold (even if average price per transaction fluctuates) naturally generate more total revenue and thus total profit.
# *   **Discounting Strategies**: While discounts don't change the *percentage* profit margin, they can stimulate higher sales volumes, thus leading to higher *absolute profit*. Regions with slightly higher average discounts (like North) might be using this effectively to drive volume.

# %% [markdown]
# ## Summary: Regional Profit Margin Discrepancies
#
# Based on the analysis, a crucial finding is that **all regions (East, North, South, West) exhibit the exact same profit margin of 0.2 (20%)**. This means that, within this dataset, there are no discrepancies in the *profit margin percentage* across regions. The profit margin is consistently 20% of total sales for every region, implying that the profit calculation (or perhaps an assumed uniform cost structure) applies uniformly across all transactions regardless of region, category, or customer segment.
#
# Therefore, the breakdown will focus on factors influencing **total sales and total profit** differences across regions, rather than *profit margin discrepancies*.
#
# ### Analysis of Regional Sales and Contributing Factors:
#
# 1.  **Average Discount % Applied per Region:**
#     *   **North** has the highest average discount (18.09%), followed by **West** (17.76%), **South** (17.51%), and **East** (17.41%).
#     *   While there are slight variations, the differences in average discount percentages across regions are not substantial enough to cause significant differences in *profit margins* given the uniform 20% rate. However, higher discounts in regions like North might contribute to higher sales volumes, leading to higher *total profit* due to increased revenue, even if the per-unit profitability remains consistent.
#
# 2.  **Product Mix Sold in Regions (Total Sales and Profit):**
#     *   **East:** 'Clothing' leads in sales, followed by 'Beauty' and 'Electronics'.
#     *   **North:** 'Electronics' leads, followed by 'Home & Kitchen' and 'Books'. This region has a strong performance in categories identified as top-sellers overall.
#     *   **South:** 'Electronics' leads significantly, followed by 'Beauty' and 'Books'. This region also shows strong alignment with overall top-performing categories.
#     *   **West:** 'Electronics' leads, followed by 'Clothing' and 'Books'.
#     *   The regional product mix generally aligns with the overall top-performing categories ('Electronics', 'Clothing', 'Books'), which are high in both sales and profit. Regions with a higher concentration of these top-performing categories (e.g., North, South, West with Electronics) tend to have higher overall total sales and profit.
#
# 3.  **Quantity vs. Price Trends per Region:**
#     *   **East:** 'Books' and 'Clothing' have the highest quantities sold, with average prices in the mid-range.
#     *   **North:** 'Home & Kitchen' and 'Electronics' have the highest quantities sold, with average prices around the overall average.
#     *   **South:** 'Books' and 'Electronics' lead in quantities, with 'Electronics' having the highest average price in the region. This might contribute to South's higher overall sales.
#     *   **West:** 'Electronics', 'Books', and 'Clothing' lead in quantities sold, with 'Electronics' having a competitive average price.
#     *   Regions that sell a higher quantity of higher-priced items (like 'Electronics' in the South and West) contribute more to total sales and, consequently, total profit, even with the same profit margin.
#
# 4.  **Customer Segment Distribution per Region (Total Sales and Profit):**
#     *   **East:** 'Wholesale' is the largest segment by sales, followed by 'Retail' and 'Online'.
#     *   **North:** 'Retail' slightly leads, followed by 'Online' and 'Wholesale'. All segments are relatively balanced.
#     *   **South:** 'Retail' is the largest segment by a notable margin, followed by 'Wholesale' and 'Online'. The strong retail presence could be a driver for this region's high sales.
#     *   **West:** 'Online' is the dominant segment by sales, followed by 'Wholesale' and 'Retail'. The strong online performance is a distinguishing factor for the West.
#     *   The dominance of different customer segments (e.g., 'Wholesale' in East, 'Retail' in South, 'Online' in West) indicates varying market structures and consumer behaviors across regions, which influences the distribution of total sales and profit, but not the profit margin percentage.
#
# ### Conclusion:
#
# While **all regions maintain a consistent 20% profit margin**, the variations in **total sales and total profit** can be attributed to:
#
# *   **Regional Demand and Product Mix**: Regions like **North** and **South** which consistently show higher total sales, benefit from a strong demand for top-performing categories, particularly 'Electronics', and to a lesser extent 'Home & Kitchen' (in North) and 'Beauty' (in South).
# *   **Customer Segment Focus**: The **South** region's high overall sales are notably driven by a strong 'Retail' customer segment, while the **West** benefits from a leading 'Online' segment. The **East** sees significant contribution from 'Wholesale'. Understanding these segment strengths is vital for targeted strategies.
# *   **Quantity Sold vs. Price**: Regions where more units of higher-value products are sold (even if average price per transaction fluctuates) naturally generate more total revenue and thus total profit.
# *   **Discounting Strategies**: While discounts don't change the *percentage* profit margin, they can stimulate higher sales volumes, thus leading to higher *absolute profit*. Regions with slightly higher average discounts (like North) might be using this effectively to drive volume.

# %%
customer_segment_profit_sales = df.groupby('Customer Segment')[['Profit (INR)', 'Total Sales (INR)']].sum()
customer_segment_profit_sales['Profit Margin'] = customer_segment_profit_sales['Profit (INR)'] / customer_segment_profit_sales['Total Sales (INR)']
customer_segment_profit_sales = customer_segment_profit_sales.sort_values(by='Profit Margin', ascending=True)

print("Customer Segment Profit, Sales, and Profit Margin (sorted by Profit Margin):")
display(customer_segment_profit_sales)
# Out:
# Customer Segment Profit, Sales, and Profit Margin (sorted by Profit Margin):
#                   Profit (INR)  Total Sales (INR)  Profit Margin
# Customer Segment
# Online             5033976.826        25169884.13            0.2
# Retail             4862238.588        24311192.94            0.2
# Wholesale          5146407.134        25732035.67            0.2

# %%
print("\nAverage Order Value by Customer Segment:")
avg_order_value_by_segment = df.groupby('Customer Segment')['Total Sales (INR)'].mean().sort_values(ascending=False)
display(avg_order_value_by_segment)
# Out:
# Average Order Value by Customer Segment:
# Customer Segment
# Wholesale    77975.865667
# Online       76041.946012
# Retail       71714.433451
# Name: Total Sales (INR), dtype: float64

# %%
print("\nAverage Discount % by Customer Segment:")
avg_discount_by_segment = df.groupby('Customer Segment')['Discount %'].mean().sort_values(ascending=False)
display(avg_discount_by_segment)
# Out:
# Average Discount % by Customer Segment:
# Customer Segment
# Wholesale    18.403030
# Online       17.498489
# Retail       17.209440
# Name: Discount %, dtype: float64

# %%
print("\nPreferred Product Categories by Customer Segment (Total Sales and Profit):")
preferred_categories_by_segment = df.groupby(['Customer Segment', 'Category'])[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by=['Customer Segment', 'Total Sales (INR)'], ascending=[True, False])
display(preferred_categories_by_segment)
# Out:
# Preferred Product Categories by Customer Segment (Total Sales and Profit):
#                                  Total Sales (INR)  Profit (INR)
# Customer Segment Category
# Online           Electronics            5862305.77   1172461.154
#                  Books                  5235531.09   1047106.218
#                  Clothing               5008162.68   1001632.536
#                  Beauty                 4647789.41    929557.882
#                  Home & Kitchen         4416095.18    883219.036
# Retail           Electronics            6622776.19   1324555.238
#                  Beauty                 4645263.73    929052.746
#                  Clothing               4514444.91    902888.982
#                  Books                  4441863.38    888372.676
#                  Home & Kitchen         4086844.73    817368.946
# Wholesale        Clothing               5591779.27   1118355.854
#                  Beauty                 5387530.91   1077506.182
# ...

# %%
print("\nPreferred Payment Methods by Customer Segment (Total Sales and Profit):")
preferred_payment_methods_by_segment = df.groupby(['Customer Segment', 'Payment Method'])[['Total Sales (INR)', 'Profit (INR)']].sum().sort_values(by=['Customer Segment', 'Total Sales (INR)'], ascending=[True, False])
display(preferred_payment_methods_by_segment)
# Out:
# Preferred Payment Methods by Customer Segment (Total Sales and Profit):
#                                  Total Sales (INR)  Profit (INR)
# Customer Segment Payment Method
# Online           COD                    4731228.87    946245.774
#                  Debit Card             4631748.20    926349.640
#                  Wallet                 4492532.66    898506.532
#                  UPI                    4407454.91    881490.982
#                  Credit Card            3798225.30    759645.060
#                  Net Banking            3108694.19    621738.838
# Retail           Net Banking            4759617.13    951923.426
#                  Wallet                 4362375.08    872475.016
#                  Debit Card             4207222.76    841444.552
#                  UPI                    4029813.86    805962.772
#                  COD                    3745046.04    749009.208
#                  Credit Card            3207118.07    641423.614
# ...

# %%
print("\nAverage Customer Rating by Customer Segment:")
avg_customer_rating_by_segment = df.groupby('Customer Segment')['Customer Rating'].mean().sort_values(ascending=False)
display(avg_customer_rating_by_segment)
# Out:
# Average Customer Rating by Customer Segment:
# Customer Segment
# Online       3.068580
# Retail       2.983481
# Wholesale    2.981818
# Name: Customer Rating, dtype: float64

# %% [markdown]
# ## Summary: Customer Segment Profitability
#
# Based on the analysis, a crucial finding is that **all customer segments (Online, Retail, Wholesale) exhibit the exact same profit margin of 0.2 (20%)**. This means that, within this dataset, there are no discrepancies in the *profit margin percentage* across customer segments. The profit margin is consistently 20% of total sales for every segment, implying that the profit calculation (or perhaps an assumed uniform cost structure) applies uniformly across all transactions regardless of customer segment, category, or region.
#
# Therefore, the breakdown will focus on factors influencing **total sales and total profit** differences across segments, rather than *profit margin discrepancies*.
#
# ### Analysis of Customer Segment Sales and Contributing Factors:
#
# 1.  **Average Order Value (AOV):**
#     *   **Wholesale** has the highest average order value (77,975.87 INR), followed by **Online** (76,041.95 INR) and **Retail** (71,714.43 INR).
#     *   Higher AOV in Wholesale contributes to its higher total sales and profit, even with the same profit margin. This indicates that Wholesale customers tend to make larger purchases per transaction.
#
# 2.  **Discount Sensitivity (Average Discount %):**
#     *   **Wholesale** has the highest average discount (18.40%), followed by **Online** (17.50%) and **Retail** (17.21%).
#     *   The slightly higher discount offered to Wholesale customers might be a strategy to incentivize larger order values, contributing to their higher total sales volume. However, given the uniform profit margin, these discounts don't erode the *percentage* profitability, but rather stimulate higher *absolute* sales and profit.
#
# 3.  **Preferred Product Categories (Total Sales and Profit):**
#     *   **Online Segment:** Primarily driven by 'Electronics', 'Books', and 'Clothing'.
#     *   **Retail Segment:** Strong preference for 'Electronics', 'Beauty', and 'Clothing'.
#     *   **Wholesale Segment:** 'Clothing' and 'Beauty' are the top categories, followed by 'Books'.
#     *   The segments show some differences in their top categories, but generally align with the overall top-performing categories (Electronics, Clothing, Books, Beauty). This indicates that all segments are contributing to the sales of high-revenue and high-profit product lines, though with slightly different emphasis.
#
# 4.  **Payment Method Trends (Total Sales and Profit):**
#     *   **Online Segment:** 'COD' and 'Debit Card' are the most preferred.
#     *   **Retail Segment:** 'Net Banking' and 'Wallet' are the leading payment methods.
#     *   **Wholesale Segment:** 'Net Banking' and 'Wallet' are also the most preferred.
#     *   While payment method preferences vary by segment, this information is more relevant for operational efficiency and customer convenience rather than directly explaining differences in profit margins or total profit, given the consistent 20% profit margin.
#
# 5.  **Impact of Customer Ratings (Average Customer Rating):**
#     *   **Online** customers give the highest average rating (3.07), followed by **Retail** (2.98) and **Wholesale** (2.98).
#     *   While there are slight differences, all segments show relatively similar average customer ratings, indicating that customer satisfaction does not significantly differ to explain major discrepancies in overall total sales or profit among segments. The ratings are generally in the 'good' range, which is positive for all segments.
#
# ### Conclusion:
#
# Although **all customer segments maintain a consistent 20% profit margin**, the variations in **total sales and total profit** are primarily influenced by:
#
# *   **Average Order Value**: Wholesale customers, with their higher AOV, contribute more to overall total sales and profit.
# *   **Discounting as a Volume Driver**: Wholesale receives slightly higher average discounts, which appears to successfully drive larger sales volumes, translating to higher total profit. This suggests discounts are effectively used to increase transaction size rather than reduce profitability per sale.
# *   **Customer Preferences**: While all segments engage with top-performing product categories, subtle differences in preferred product mix contribute to the distribution of total sales and profit across segments. However, no segment appears to be significantly disadvantaged by their product preferences given the uniform profit margin.
#
# In essence, while no segment is *less profitable* in terms of percentage margin, segments like 'Wholesale' generate a higher *absolute profit* due to a higher average order value and potentially more effective volume-driving discounts.

# %% [markdown]
# ## Summary:
#
# ### Q&A
#
# 1.  **What factors contributed to the sales spike in July 2024?**
#     The sales spike in July 2024, which saw total sales reach INR 7,637,324.95 and profit at INR 1,527,464.99, was driven by strong performance across top-selling categories like 'Clothing' (sales of INR 1,911,102.43) and 'Electronics' (sales of INR 1,747,192.01). The 'North' region led with sales of INR 2,282,479.15, indicating robust widespread regional activity. Strategic discounting at an average of 17.06% helped attract customers without significantly eroding profit margins, and 'Wholesale' customers contributed significantly with sales of INR 2,739,128.27. Additionally, a higher average price per item (INR 26,205.89) or transaction also boosted total sales values.
#
# 2.  **What factors contributed to the sales drop in February 2025?**
#     The sales drop in February 2025, which recorded the lowest total sales of INR 1,506,096.20 and profit of INR 301,219.24, was primarily due to a generalized decrease in demand across all product categories, customer segments, and regions. All categories experienced significantly lower sales compared to peak months, with 'Beauty' having the highest sales (INR 552,514.13) in this low month, and 'Clothing' being the lowest (INR 141,050.13). All regions showed considerably lower sales, and all customer segments displayed reduced activity. A slightly higher average discount of 17.81% did not stimulate sales, suggesting demand was the primary issue. Furthermore, a lower average item price of INR 22,298.03 indicated purchases of lower-value items or a reduced volume of higher-priced goods.
#
# 3.  **Why are certain products or categories underperforming?**
#     'Home & Kitchen' underperforms due to low demand (lowest total quantity sold at 579 units) and potentially less aggressive promotional efforts (lowest average discount at 16.80%), despite having the highest average customer rating (3.14), suggesting good product quality.
#     'Beauty' underperforms primarily due to low customer satisfaction, evidenced by the lowest average customer rating (2.87) among all categories. Although it had a moderate average discount (17.53%) and the second-lowest quantity sold (583 units), discounts were not enough to compensate for the fundamental issue of customer dissatisfaction.
#
# 4.  **Why might profit margin be lower in specific regions?**
#     Based on the analysis, there are **no discrepancies in profit margin percentage across regions**. All regions (East, North, South, West) consistently exhibited an identical profit margin of 20%. The variations observed were in *total sales and total profit*, which are influenced by regional demand and product mix (e.g., 'Electronics' driving sales in North, South, West), customer segment focus (e.g., 'Retail' dominance in the South), the quantity of higher-priced items sold, and the effectiveness of discounting strategies in driving sales volume.
#
# 5.  **Why do some customer segments generate lower profit?**
#     Similarly, there are **no discrepancies in profit margin percentage across customer segments**. All customer segments (Online, Retail, Wholesale) consistently exhibited an identical profit margin of 20%. Differences in *total sales and total profit* between segments are influenced by their Average Order Value (AOV) and how discounting strategies affect sales volume. 'Wholesale' has the highest AOV (INR 77,975.87) and receives slightly higher average discounts (18.40%), which appears to drive larger sales volumes and thus higher *absolute profit*, without eroding the percentage profit margin.
#
# ### Data Analysis Key Findings
#
# *   **Highest Sales Month (July 2024) Characteristics:**
#     *   Total sales: INR 7,637,324.95; Total profit: INR 1,527,464.99.
#     *   Top Categories: 'Clothing' (INR 1,911,102.43 sales) and 'Electronics' (INR 1,747,192.01 sales).
#     *   Leading Region: 'North' (INR 2,282,479.15 sales).
#     *   Average Discount: 17.06%.
#     *   Key Customer Segment: 'Wholesale' (INR 2,739,128.27 sales).
#     *   Average Price: INR 26,205.89.
#
# *   **Lowest Sales/Profit Month (February 2025) Characteristics:**
#     *   Total sales: INR 1,506,096.20; Total profit: INR 301,219.24.
#     *   Lowest performing categories include 'Clothing' (INR 141,050.13 sales) and 'Home & Kitchen' (INR 182,108.49 sales) compared to July, indicating a broad reduction in demand.
#     *   All regions experienced a sharp decline in sales, with 'North' (INR 235,772.49 sales) and 'South' (INR 340,403.78 sales) significantly lower than their peak performance.
#     *   Average Discount: 17.81%, slightly higher than the highest sales month but ineffective in stimulating demand.
#     *   All customer segments showed substantially reduced activity.
#     *   Average Price: INR 22,298.03, notably lower than July, suggesting customers purchased lower-priced items or fewer high-value products.
#
# *   **Underperforming Categories ('Home & Kitchen' and 'Beauty'):**
#     *   **Home & Kitchen:** High customer satisfaction (average rating 3.14) but lowest total quantity sold (579 units) and lowest average discount (16.80%).
#     *   **Beauty:** Lowest average customer rating (2.87) and second-lowest total quantity sold (583 units), indicating significant customer dissatisfaction.
#
# *   **Regional Profitability:**
#     *   All regions (East, North, South, West) exhibit a **uniform profit margin of 20%**. There are no actual profit margin discrepancies between regions within the dataset.
#     *   Differences in *total sales and total profit* are driven by variations in product mix (e.g., higher concentration of 'Electronics' in North, South, West), customer segment dominance (e.g., 'Retail' in South, 'Online' in West), quantity sold of higher-priced items, and how discounting influences sales volume.
#
# *   **Customer Segment Profitability:**
#     *   All customer segments (Online, Retail, Wholesale) also exhibit a **uniform profit margin of 20%**. There are no actual profit margin discrepancies between segments.
#     *   Differences in *total sales and total profit* are primarily influenced by Average Order Value (AOV), with 'Wholesale' having the highest AOV (INR 77,975.87) and receiving the highest average discount (18.40%), leading to higher absolute total sales and profit.
#
# *   **Data Limitations:**
#     *   Competitor pricing could not be analyzed for understanding product underperformance.
#     *   Granular time data (e.g., peak hours) was not available for deeper analysis of sales spikes or drops.
#
# ### Insights or Next Steps
#
# *   **Optimize Seasonal Strategies:** Develop targeted marketing campaigns and inventory management for February to counteract the natural post-holiday seasonal dip. For July, capitalize on the strong demand in 'Clothing', 'Electronics', and 'Wholesale' segments with proactive inventory and promotional planning.
# *   **Address Category-Specific Issues:** For 'Beauty', prioritize product quality improvements and customer experience enhancements to boost satisfaction and ratings. For 'Home & Kitchen', explore aggressive promotional strategies, new product lines, or targeted marketing to increase demand and sales volume, given its already high customer satisfaction.
